# %% [markdown]
# # Project 2: Ames Housing Saleprice Prediction
# ---
#
# Project notebook organisation:<br>
# **[1 - Data Cleaning]** (current notebook)<br>
# [2 - Pre-processing](./2_eda.ipynb)<br>
# [3 - Model Tuning and Insights](./3_model_tuning_and_insights.ipynb)<br>
# [3.1 - Model Performance with Automated Feature Selection](3_(appendix)_automated_feature_selection)<br>
# <br>
# <br>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# ## Introduction and Problem statement

# %% [markdown]
# This second notebook in the project will cover EDA and data preprocessing based on the cleaned data from the previous notebook.

# %% [markdown]
# ## Executive Summary

# %% [markdown]
# # Workbook 1: Data-cleaning

# %% [markdown]
# ## Contents of this workbook

# %% [markdown]
# 1. [Initial analysis for training set](#Initial-analysis-for-training-set)
# 2. [Understanding null values](#Understanding-null-values)
#   1. [Analysing numerical columns](#Analysing-numerical-columns)
#   1. [Analysing categorical columns](#Analysing-categorical-columns)
# 1. [Summary of null values](#Summary-of-null-values)
# 1. [Investigate and resolve low nullcounts](#Investigate-and-resolve-low-nullcounts)
# 1. [Investigate and resolve high nullcounts](#Investigate-and-resolve-high-nullcounts)
# 1. [Confirmation of processed test data](#Confirmation-of-processed-test-data)
# 1. [Initial analysis for test set](#Initial-analysis-for-test-set)
# 1. [Investigate and resolve nullcounts](#Investigate-and-resolve-nullcounts)
# 1. [Confirmation of processed train data](#Confirmation-of-processed-train-data)
# 1. [Summary](#Summary)

# %% [markdown]
# ## Functions used

# %%
#This function returns a report of the number of null values in their respective columns.

def nullreport(df):
    df_nullcount = pd.DataFrame(df.isnull().sum(), columns = ['nulls'])
    df_nullcount = df_nullcount[df_nullcount['nulls'] != 0]
    sns.heatmap(ames_train.isnull())
    print(df_nullcount.shape)
    return df_nullcount

# %% [markdown]
# ## Initial analysis for training set
# ---

# %%
# Import and read the CSV. Assign test.csv to variable ames_test and train.csv to ames_train

ames_train = pd.read_csv("./datasets/train.csv")
ames_test = pd.read_csv("./datasets/test.csv")

#Make all columns lowercase and replace spaces with '_'
ames_train.columns = ames_train.columns.str.lower()
ames_train.columns = ames_train.columns.str.replace(' ', '_')

# %%
ames_train.head()
# Out:
#     id        pid  ms_subclass ms_zoning  lot_frontage  lot_area street alley  \
# 0  109  533352170           60        RL           NaN     13517   Pave   NaN
# 1  544  531379050           60        RL          43.0     11492   Pave   NaN
# 2  153  535304180           20        RL          68.0      7922   Pave   NaN
# 3  318  916386060           60        RL          73.0      9802   Pave   NaN
# 4  255  906425045           50        RL          82.0     14235   Pave   NaN
#
#   lot_shape land_contour  ... screen_porch pool_area pool_qc fence  \
# 0       IR1          Lvl  ...            0         0     NaN   NaN
# 1       IR1          Lvl  ...            0         0     NaN   NaN
# 2       Reg          Lvl  ...            0         0     NaN   NaN
# 3       Reg          Lvl  ...            0         0     NaN   NaN
# 4       IR1          Lvl  ...            0         0     NaN   NaN
#
#   misc_feature misc_val mo_sold yr_sold  sale_type  saleprice
# 0          NaN        0       3    2010        WD      130500
# 1          NaN        0       4    2009        WD      220000
# 2          NaN        0       1    2010        WD      109000
# 3          NaN        0       4    2010        WD      174000
# 4          NaN        0       3    2010        WD      138500
#
# [5 rows x 81 columns]

# %%
ames_train.shape
# Out:
# (2051, 81)

# %%
ames_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2051 entries, 0 to 2050
# Data columns (total 81 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               2051 non-null   int64
#  1   pid              2051 non-null   int64
#  2   ms_subclass      2051 non-null   int64
#  3   ms_zoning        2051 non-null   object
#  4   lot_frontage     1721 non-null   float64
#  5   lot_area         2051 non-null   int64
#  6   street           2051 non-null   object
#  7   alley            140 non-null    object
#  8   lot_shape        2051 non-null   object
#  9   land_contour     2051 non-null   object
#  10  utilities        2051 non-null   object
#  11  lot_config       2051 non-null   object
#  12  land_slope       2051 non-null   object
#  13  neighborhood     2051 non-null   object
#  14  condition_1      2051 non-null   object
#  15  condition_2      2051 non-null   object
#  16  bldg_type        2051 non-null   object
#  17  house_style      2051 non-null   object
#  18  overall_qual     2051 non-null   int64
#  19  overall_cond     2051 non-null   int64
#  20  year_built       2051 non-null   int64
#  21  year_remod/add   2051 non-null   int64
#  22  roof_style       2051 non-null   object
#  23  roof_matl        2051 non-null   object
#  24  exterior_1st     2051 non-null   object
#  25  exterior_2nd     2051 non-null   object
#  26  mas_vnr_type     2029 non-null   object
#  27  mas_vnr_area     2029 non-null   float64
#  28  exter_qual       2051 non-null   object
#  29  exter_cond       2051 non-null   object
#  30  foundation       2051 non-null   object
#  31  bsmt_qual        1996 non-null   object
#  32  bsmt_cond        1996 non-null   object
#  33  bsmt_exposure    1993 non-null   object
#  34  bsmtfin_type_1   1996 non-null   object
#  35  bsmtfin_sf_1     2050 non-null   float64
#  36  bsmtfin_type_2   1995 non-null   object
#  37  bsmtfin_sf_2     2050 non-null   float64
#  38  bsmt_unf_sf      2050 non-null   float64
#  39  total_bsmt_sf    2050 non-null   float64
#  40  heating          2051 non-null   object
#  41  heating_qc       2051 non-null   object
#  42  central_air      2051 non-null   object
#  43  electrical       2051 non-null   object
#  44  1st_flr_sf       2051 non-null   int64
#  45  2nd_flr_sf       2051 non-null   int64
#  46  low_qual_fin_sf  2051 non-null   int64
#  47  gr_liv_area      2051 non-null   int64
#  48  bsmt_full_bath   2049 non-null   float64
#  49  bsmt_half_bath   2049 non-null   float64
#  50  full_bath        2051 non-null   int64
#  51  half_bath        2051 non-null   int64
#  52  bedroom_abvgr    2051 non-null   int64
#  53  kitchen_abvgr    2051 non-null   int64
#  54  kitchen_qual     2051 non-null   object
#  55  totrms_abvgrd    2051 non-null   int64
#  56  functional       2051 non-null   object
#  57  fireplaces       2051 non-null   int64
#  58  fireplace_qu     1051 non-null   object
#  59  garage_type      1938 non-null   object
#  60  garage_yr_blt    1937 non-null   float64
#  61  garage_finish    1937 non-null   object
#  62  garage_cars      2050 non-null   float64
#  63  garage_area      2050 non-null   float64
#  64  garage_qual      1937 non-null   object
#  65  garage_cond      1937 non-null   object
#  66  paved_drive      2051 non-null   object
#  67  wood_deck_sf     2051 non-null   int64
#  68  open_porch_sf    2051 non-null   int64
#  69  enclosed_porch   2051 non-null   int64
#  70  3ssn_porch       2051 non-null   int64
#  71  screen_porch     2051 non-null   int64
#  72  pool_area        2051 non-null   int64
#  73  pool_qc          9 non-null      object
#  74  fence            400 non-null    object
#  75  misc_feature     65 non-null     object
#  76  misc_val         2051 non-null   int64
#  77  mo_sold          2051 non-null   int64
#  78  yr_sold          2051 non-null   int64
#  79  sale_type        2051 non-null   object
#  80  saleprice        2051 non-null   int64
# dtypes: float64(11), int64(28), object(42)
# memory usage: 1.3+ MB

# %% [markdown]
# Dataset has 2051 rows and 80 columns

# %% [markdown]
# * The dataset contains 2051 entries with 81 features, representing characteristics of houses sold between 2006-2010.
# * The data is split into different categories:
#     * Numerical
#     * Categorical
#     * Categorical (Ordinal)
# * The highest selling price is \\$611,657 and the lowest is \\$12,789

# %% [markdown]
# ## Understanding null values
# ---

# %%
nullreport(ames_train)
# Out:
# (26, 1)
#                 nulls
# lot_frontage      330
# alley            1911
# mas_vnr_type       22
# mas_vnr_area       22
# bsmt_qual          55
# bsmt_cond          55
# bsmt_exposure      58
# bsmtfin_type_1     55
# bsmtfin_sf_1        1
# bsmtfin_type_2     56
# bsmtfin_sf_2        1
# bsmt_unf_sf         1
# total_bsmt_sf       1
# bsmt_full_bath      2
# bsmt_half_bath      2
# fireplace_qu     1000
# garage_type       113
# garage_yr_blt     114
# garage_finish     114
# garage_cars         1
# garage_area         1
# garage_qual       114
# garage_cond       114
# pool_qc          2042
# fence            1651
# misc_feature     1986

# %%
#Visualise where the null columns are
plt.figure(figsize=(15,9))
           
sns.heatmap(ames_train.isnull())

# %%
#return all columns with null values and their respective number of null values
# Solution from https://dzone.com/articles/pandas-find-rows-where-columnfield-is-null
null_columns=ames_train.columns[ames_train.isnull().any()]
ames_train[null_columns].isnull().sum()
# Out:
# lot_frontage       330
# alley             1911
# mas_vnr_type        22
# mas_vnr_area        22
# bsmt_qual           55
# bsmt_cond           55
# bsmt_exposure       58
# bsmtfin_type_1      55
# bsmtfin_sf_1         1
# bsmtfin_type_2      56
# bsmtfin_sf_2         1
# bsmt_unf_sf          1
# total_bsmt_sf        1
# bsmt_full_bath       2
# bsmt_half_bath       2
# fireplace_qu      1000
# garage_type        113
# garage_yr_blt      114
# garage_finish      114
# garage_cars          1
# garage_area          1
# garage_qual        114
# garage_cond        114
# pool_qc           2042
# fence             1651
# misc_feature      1986
# dtype: int64

# %%
# Count number of null columns
null_columns.value_counts().sum()
# Out:
# 26

# %% [markdown]
# 26 out of 81 columns appear to have null values with differing severity. Due to the mixed nature of the dataset, i next analysie categorical and numerical columns separately.

# %% [markdown]
# ### Analysing numerical columns

# %%
# Isolate columns with numerical information 
# solution sourced from https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.select_dtypes.html
num_cols = ames_train.select_dtypes(exclude=['object'])
num_cols
# Out:
#         id        pid  ms_subclass  lot_frontage  lot_area  overall_qual  \
# 0      109  533352170           60           NaN     13517             6
# 1      544  531379050           60          43.0     11492             7
# 2      153  535304180           20          68.0      7922             5
# 3      318  916386060           60          73.0      9802             5
# 4      255  906425045           50          82.0     14235             6
# ...    ...        ...          ...           ...       ...           ...
# 2046  1587  921126030           20          79.0     11449             8
# 2047   785  905377130           30           NaN     12342             4
# 2048   916  909253010           50          57.0      7558             6
# 2049   639  535179160           20          80.0     10400             4
# 2050    10  527162130           60          60.0      7500             7
#
#       overall_cond  year_built  year_remod/add  mas_vnr_area  ...  \
# 0                8        1976            2005         289.0  ...
# 1                5        1996            1997         132.0  ...
# 2                7        1953            2007           0.0  ...
# 3                5        2006            2007           0.0  ...
# 4                8        1900            1993           0.0  ...
# ...            ...         ...             ...           ...  ...
# 2046             5        2007            2007           0.0  ...
# 2047             5        1940            1950           0.0  ...
# 2048             6        1928            1950           0.0  ...
# 2049             5        1956            1956           0.0  ...
# 2050             5        1999            1999           0.0  ...
#
#       wood_deck_sf  open_porch_sf  enclosed_porch  3ssn_porch  screen_porch  \
# 0                0             44               0           0             0
# 1                0             74               0           0             0
# 2                0             52               0           0             0
# 3              100              0               0           0             0
# 4                0             59               0           0             0
# ...            ...            ...             ...         ...           ...
# 2046             0            276               0           0             0
# 2047           158              0               0           0             0
# 2048             0              0               0           0             0
# 2049             0            189             140           0             0
# 2050           140             60               0           0             0
#
#       pool_area  misc_val  mo_sold  yr_sold  saleprice
# 0             0         0        3     2010     130500
# 1             0         0        4     2009     220000
# 2             0         0        1     2010     109000
# 3             0         0        4     2010     174000
# 4             0         0        3     2010     138500
# ...         ...       ...      ...      ...        ...
# 2046          0         0        1     2008     298751
# 2047          0         0        3     2009      82500
# 2048          0         0        3     2009     177000
# 2049          0         0       11     2009     144000
# 2050          0         0        6     2010     189000
#
# [2051 rows x 39 columns]

# %%
#Find out the numerical columns that have null values
num_cols.isnull().sum()
# Out:
# id                   0
# pid                  0
# ms_subclass          0
# lot_frontage       330
# lot_area             0
# overall_qual         0
# overall_cond         0
# year_built           0
# year_remod/add       0
# mas_vnr_area        22
# bsmtfin_sf_1         1
# bsmtfin_sf_2         1
# bsmt_unf_sf          1
# total_bsmt_sf        1
# 1st_flr_sf           0
# 2nd_flr_sf           0
# low_qual_fin_sf      0
# gr_liv_area          0
# bsmt_full_bath       2
# bsmt_half_bath       2
# full_bath            0
# half_bath            0
# bedroom_abvgr        0
# kitchen_abvgr        0
# totrms_abvgrd        0
# fireplaces           0
# garage_yr_blt      114
# garage_cars          1
# garage_area          1
# wood_deck_sf         0
# open_porch_sf        0
# enclosed_porch       0
# 3ssn_porch           0
# screen_porch         0
# pool_area            0
# misc_val             0
# mo_sold              0
# yr_sold              0
# saleprice            0
# dtype: int64

# %%
#Visualise missing data for numerical information

sns.heatmap(num_cols.isnull())

# %%
#FInd out what the dtypes are
num_cols.dtypes
# Out:
# id                   int64
# pid                  int64
# ms_subclass          int64
# lot_frontage       float64
# lot_area             int64
# overall_qual         int64
# overall_cond         int64
# year_built           int64
# year_remod/add       int64
# mas_vnr_area       float64
# bsmtfin_sf_1       float64
# bsmtfin_sf_2       float64
# bsmt_unf_sf        float64
# total_bsmt_sf      float64
# 1st_flr_sf           int64
# 2nd_flr_sf           int64
# low_qual_fin_sf      int64
# gr_liv_area          int64
# bsmt_full_bath     float64
# bsmt_half_bath     float64
# full_bath            int64
# half_bath            int64
# bedroom_abvgr        int64
# kitchen_abvgr        int64
# totrms_abvgrd        int64
# fireplaces           int64
# garage_yr_blt      float64
# garage_cars        float64
# garage_area        float64
# wood_deck_sf         int64
# open_porch_sf        int64
# enclosed_porch       int64
# 3ssn_porch           int64
# screen_porch         int64
# pool_area            int64
# misc_val             int64
# mo_sold              int64
# yr_sold              int64
# saleprice            int64
# dtype: object

# %% [markdown]
# ### Analysing categorical columns
# ---

# %%
# Isolate columns with information as object information 
# solution sourced from https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.select_dtypes.html
cat_cols = ames_train.select_dtypes(include=['object'])

cat_cols
# Out:
#      ms_zoning street alley lot_shape land_contour utilities lot_config  \
# 0           RL   Pave   NaN       IR1          Lvl    AllPub    CulDSac
# 1           RL   Pave   NaN       IR1          Lvl    AllPub    CulDSac
# 2           RL   Pave   NaN       Reg          Lvl    AllPub     Inside
# 3           RL   Pave   NaN       Reg          Lvl    AllPub     Inside
# 4           RL   Pave   NaN       IR1          Lvl    AllPub     Inside
# ...        ...    ...   ...       ...          ...       ...        ...
# 2046        RL   Pave   NaN       IR1          HLS    AllPub     Inside
# 2047        RL   Pave   NaN       IR1          Lvl    AllPub     Inside
# 2048        RL   Pave   NaN       Reg          Bnk    AllPub     Inside
# 2049        RL   Pave   NaN       Reg          Lvl    AllPub     Corner
# 2050        RL   Pave   NaN       Reg          Lvl    AllPub     Inside
#
#      land_slope neighborhood condition_1  ... fireplace_qu garage_type  \
# 0           Gtl       Sawyer        RRAe  ...          NaN      Attchd
# 1           Gtl      SawyerW        Norm  ...           TA      Attchd
# 2           Gtl        NAmes        Norm  ...          NaN      Detchd
# 3           Gtl       Timber        Norm  ...          NaN     BuiltIn
# 4           Gtl      SawyerW        Norm  ...          NaN      Detchd
# ...         ...          ...         ...  ...          ...         ...
# 2046        Gtl       Timber        Norm  ...           Gd      Attchd
# 2047        Gtl      Edwards        Norm  ...          NaN      Detchd
# 2048        Gtl      Crawfor        Norm  ...           TA      Detchd
# 2049        Gtl        NAmes        Norm  ...           Gd      Attchd
# 2050        Gtl      Gilbert        Norm  ...           TA      Attchd
#
#      garage_finish garage_qual garage_cond paved_drive pool_qc fence  \
# 0              RFn          TA          TA           Y     NaN   NaN
# 1              RFn          TA          TA           Y     NaN   NaN
# 2              Unf          TA          TA           Y     NaN   NaN
# 3              Fin          TA          TA           Y     NaN   NaN
# 4              Unf          TA          TA           N     NaN   NaN
# ...            ...         ...         ...         ...     ...   ...
# 2046           Fin          TA          TA           Y     NaN   NaN
# 2047           Unf          TA          TA           Y     NaN   NaN
# 2048           Unf          Fa          Fa           Y     NaN   NaN
# 2049           Unf          TA          TA           Y     NaN   NaN
# 2050           Fin          TA          TA           Y     NaN   NaN
#
#      misc_feature sale_type
# 0             NaN       WD
# 1             NaN       WD
# 2             NaN       WD
# 3             NaN       WD
# 4             NaN       WD
# ...           ...       ...
# 2046          NaN       WD
# 2047          NaN       WD
# 2048          NaN       WD
# 2049          NaN       WD
# 2050          NaN       WD
#
# [2051 rows x 42 columns]

# %%
#Find out which columns have null values

cat_cols.isnull().sum()
# Out:
# ms_zoning            0
# street               0
# alley             1911
# lot_shape            0
# land_contour         0
# utilities            0
# lot_config           0
# land_slope           0
# neighborhood         0
# condition_1          0
# condition_2          0
# bldg_type            0
# house_style          0
# roof_style           0
# roof_matl            0
# exterior_1st         0
# exterior_2nd         0
# mas_vnr_type        22
# exter_qual           0
# exter_cond           0
# foundation           0
# bsmt_qual           55
# bsmt_cond           55
# bsmt_exposure       58
# bsmtfin_type_1      55
# bsmtfin_type_2      56
# heating              0
# heating_qc           0
# central_air          0
# electrical           0
# kitchen_qual         0
# functional           0
# fireplace_qu      1000
# garage_type        113
# garage_finish      114
# garage_qual        114
# garage_cond        114
# paved_drive          0
# pool_qc           2042
# fence             1651
# misc_feature      1986
# sale_type            0
# dtype: int64

# %%
sns.heatmap(cat_cols.isnull())

# %% [markdown]
# ## Summary of null values
# ---

# %% [markdown]
# There are 26 columns with varying amounts of null values, ranging from 1 to 2042.
#
# For numerical columns, only 3 columns have significant missing values.
#
# For categorical columns there are 15 columns with significant (>55) null columns.
#
# Looking at the categorical columns and comparing their unique values with the [data dictionary](https://www.kaggle.com/c/dsi-us-6-project-2-regression-challenge/data), it is likely that the null values represent houses without those features, e.g. without a garage, pool, or fireplace.
#
# The missing values in some numerical columns correspond to those as well, e.g. houses without masonry veneer also have null values for mas_vnr_area and mas_vnr_type.
#
# The nulls in these categorical columns will be filled with "None", and those in numerical columns will be filled with 0.
#
# Some columns only have 1 or 2 null values, these are likely errors in recording and will be dropped.

# %%
def nullreport(df):
    df_nullcount = pd.DataFrame(df.isnull().sum(), columns = ['nulls'])
    df_nullcount = df_nullcount[df_nullcount['nulls'] != 0]
    print(df_nullcount.shape)
    return df_nullcount

# %%
nullreport(ames_train)
# Out:
# (0, 1)
# Empty DataFrame
# Columns: [nulls]
# Index: []

# %%
# Print a list of nulls for columns containing nulls

ames_train_nullcount = pd.DataFrame(ames_train.isnull().sum(), columns = ['nulls'])
ames_train_nullcount = ames_train_nullcount[ames_train_nullcount['nulls'] != 0]
print(ames_train_nullcount.shape)
ames_train_nullcount
# Out:
# (26, 1)
#                 nulls
# lot_frontage      330
# alley            1911
# mas_vnr_type       22
# mas_vnr_area       22
# bsmt_qual          55
# bsmt_cond          55
# bsmt_exposure      58
# bsmtfin_type_1     55
# bsmtfin_sf_1        1
# bsmtfin_type_2     56
# bsmtfin_sf_2        1
# bsmt_unf_sf         1
# total_bsmt_sf       1
# bsmt_full_bath      2
# bsmt_half_bath      2
# fireplace_qu     1000
# garage_type       113
# garage_yr_blt     114
# garage_finish     114
# garage_cars         1
# garage_area         1
# garage_qual       114
# garage_cond       114
# pool_qc          2042
# fence            1651
# misc_feature     1986

# %% [markdown]
# ## Investigate and resolve low nullcounts

# %% [markdown]
# The main hypothesis for variables with low null counts such as 'bsmtfin_sf_1' is that there are errors in recording and should be dropped.
#
# I investigate this hypothesis by calling all the rows with low null counts and looking of overlaps in rows.

# %%
ames_train.loc[ames_train['bsmtfin_sf_1'].isnull()]
# Out:
#         id        pid  ms_subclass ms_zoning  lot_frontage  lot_area street  \
# 1327  1342  903230120           20        RM          99.0      5940   Pave
#
#      alley lot_shape land_contour  ... screen_porch pool_area pool_qc  fence  \
# 1327   NaN       IR1          Lvl  ...            0         0     NaN  MnPrv
#
#      misc_feature misc_val mo_sold yr_sold  sale_type  saleprice
# 1327          NaN        0       4    2008      ConLD      79000
#
# [1 rows x 81 columns]

# %%
ames_train.loc[ames_train['bsmtfin_sf_2'].isnull()]
# Out:
#         id        pid  ms_subclass ms_zoning  lot_frontage  lot_area street  \
# 1327  1342  903230120           20        RM          99.0      5940   Pave
#
#      alley lot_shape land_contour  ... screen_porch pool_area pool_qc  fence  \
# 1327   NaN       IR1          Lvl  ...            0         0     NaN  MnPrv
#
#      misc_feature misc_val mo_sold yr_sold  sale_type  saleprice
# 1327          NaN        0       4    2008      ConLD      79000
#
# [1 rows x 81 columns]

# %%
ames_train.loc[ames_train['bsmt_unf_sf'].isnull()]
# Out:
#         id        pid  ms_subclass ms_zoning  lot_frontage  lot_area street  \
# 1327  1342  903230120           20        RM          99.0      5940   Pave
#
#      alley lot_shape land_contour  ... screen_porch pool_area pool_qc  fence  \
# 1327   NaN       IR1          Lvl  ...            0         0     NaN  MnPrv
#
#      misc_feature misc_val mo_sold yr_sold  sale_type  saleprice
# 1327          NaN        0       4    2008      ConLD      79000
#
# [1 rows x 81 columns]

# %%
ames_train.loc[ames_train['total_bsmt_sf'].isnull()]
# Out:
#         id        pid  ms_subclass ms_zoning  lot_frontage  lot_area street  \
# 1327  1342  903230120           20        RM          99.0      5940   Pave
#
#      alley lot_shape land_contour  ... screen_porch pool_area pool_qc  fence  \
# 1327   NaN       IR1          Lvl  ...            0         0     NaN  MnPrv
#
#      misc_feature misc_val mo_sold yr_sold  sale_type  saleprice
# 1327          NaN        0       4    2008      ConLD      79000
#
# [1 rows x 81 columns]

# %%
ames_train.loc[ames_train['bsmt_full_bath'].isnull()]
# Out:
#         id        pid  ms_subclass ms_zoning  lot_frontage  lot_area street  \
# 616   1498  908154080           20        RL         123.0     47007   Pave
# 1327  1342  903230120           20        RM          99.0      5940   Pave
#
#      alley lot_shape land_contour  ... screen_porch pool_area pool_qc  fence  \
# 616    NaN       IR1          Lvl  ...            0         0     NaN    NaN
# 1327   NaN       IR1          Lvl  ...            0         0     NaN  MnPrv
#
#      misc_feature misc_val mo_sold yr_sold  sale_type  saleprice
# 616           NaN        0       7    2008        WD      284700
# 1327          NaN        0       4    2008      ConLD      79000
#
# [2 rows x 81 columns]

# %%
ames_train.loc[ames_train['bsmt_half_bath'].isnull()]
# Out:
#         id        pid  ms_subclass ms_zoning  lot_frontage  lot_area street  \
# 616   1498  908154080           20        RL         123.0     47007   Pave
# 1327  1342  903230120           20        RM          99.0      5940   Pave
#
#      alley lot_shape land_contour  ... screen_porch pool_area pool_qc  fence  \
# 616    NaN       IR1          Lvl  ...            0         0     NaN    NaN
# 1327   NaN       IR1          Lvl  ...            0         0     NaN  MnPrv
#
#      misc_feature misc_val mo_sold yr_sold  sale_type  saleprice
# 616           NaN        0       7    2008        WD      284700
# 1327          NaN        0       4    2008      ConLD      79000
#
# [2 rows x 81 columns]

# %%
ames_train.loc[ames_train['garage_cars'].isnull()]
# Out:
#         id        pid  ms_subclass ms_zoning  lot_frontage  lot_area street  \
# 1712  2237  910201180           70        RM          50.0      9060   Pave
#
#      alley lot_shape land_contour  ... screen_porch pool_area pool_qc  fence  \
# 1712   NaN       Reg          Lvl  ...            0         0     NaN  MnPrv
#
#      misc_feature misc_val mo_sold yr_sold  sale_type  saleprice
# 1712          NaN        0       3    2007        WD      150909
#
# [1 rows x 81 columns]

# %%
ames_train.loc[ames_train['garage_area'].isnull()]
# Out:
#         id        pid  ms_subclass ms_zoning  lot_frontage  lot_area street  \
# 1712  2237  910201180           70        RM          50.0      9060   Pave
#
#      alley lot_shape land_contour  ... screen_porch pool_area pool_qc  fence  \
# 1712   NaN       Reg          Lvl  ...            0         0     NaN  MnPrv
#
#      misc_feature misc_val mo_sold yr_sold  sale_type  saleprice
# 1712          NaN        0       3    2007        WD      150909
#
# [1 rows x 81 columns]

# %% [markdown]
# Rows that stand out:
#     * 1327
#     * 616
#     * 1712
#
# These rows consistently display missing information overlapping with each other and should be dropped.

# %%
ames_train.drop([1327, 616, 1712], inplace = True)

# %%
# Refresh list of nulls for columns containing nulls

ames_train_nullcount = pd.DataFrame(ames_train.isnull().sum(), columns = ['nulls'])
ames_train_nullcount = ames_train_nullcount[ames_train_nullcount['nulls'] != 0]
print(ames_train_nullcount.shape)
ames_train_nullcount
# Out:
# (18, 1)
#                 nulls
# lot_frontage      330
# alley            1908
# mas_vnr_type       22
# mas_vnr_area       22
# bsmt_qual          53
# bsmt_cond          53
# bsmt_exposure      56
# bsmtfin_type_1     53
# bsmtfin_type_2     54
# fireplace_qu      998
# garage_type       113
# garage_yr_blt     113
# garage_finish     113
# garage_qual       113
# garage_cond       113
# pool_qc          2039
# fence            1650
# misc_feature     1983

# %% [markdown]
# We now have 18 more features to clean.
#
# The remaining features appear to have a few different themes:
#  * Basements
#  * Frontage
#  * Alley
#  * Masonry Veneer
#  * Fireplace
#  * Garage
#  * Pool
#  * Fence
#  * Misc Features
#
# Features that are close to their respective themes have the equivalent number of null values.
#
# I posit that the null values explain the absense of these features. An appropriate action would be to replace these values with either 'none' or '0'.

# %% [markdown]
# ## Investigate and resolve high nullcounts

# %% [markdown]
# ### Mas_vnr features

# %%
#Selecting the columns with null values and assigning them to the variable mas_vnr for data cleaning
# Nan values seem to indicate the absence of mas_vnr. I shall replace NaN in Mass_vnr_typr with 'none'
# and mas_vnr_area with 0.0
mas_vnr = ames_train.loc[ames_train['mas_vnr_area'].isnull()][['mas_vnr_type','mas_vnr_area']]
print(mas_vnr.shape)
mas_vnr
# Out:
# (22, 2)
#      mas_vnr_type  mas_vnr_area
# 22            NaN           NaN
# 41            NaN           NaN
# 86            NaN           NaN
# 212           NaN           NaN
# 276           NaN           NaN
# 338           NaN           NaN
# 431           NaN           NaN
# 451           NaN           NaN
# 591           NaN           NaN
# 844           NaN           NaN
# 913           NaN           NaN
# 939           NaN           NaN
# 1025          NaN           NaN
# 1244          NaN           NaN
# 1306          NaN           NaN
# 1430          NaN           NaN
# 1434          NaN           NaN
# 1606          NaN           NaN
# 1699          NaN           NaN
# 1815          NaN           NaN
# 1820          NaN           NaN
# 1941          NaN           NaN

# %%
ames_train['mas_vnr_type'].unique()
# Out:
# array(['BrkFace', 'None', nan, 'Stone', 'BrkCmn'], dtype=object)

# %%
ames_train['mas_vnr_type'] = ames_train['mas_vnr_type'].fillna('none')

ames_train['mas_vnr_area'] = ames_train['mas_vnr_area'].fillna(0.0)

# %% [markdown]
# ### Basement features

# %%
# entries 1456, 1547, 1997 appear to have basements even though BsmtExposure is a NaN value. The description seems to fit an
#unfinished basement which is relatively high. for these three rows, I will fill bsmnt_exposure = 'No'
#The other values will be filled with 'None'

bsmt = ames_train.loc[ames_train['bsmt_exposure'].isnull()][['bsmt_exposure','bsmt_cond', 'bsmt_qual','bsmtfin_type_1','bsmtfin_type_2']]
bsmt
# Out:
#      bsmt_exposure bsmt_cond bsmt_qual bsmtfin_type_1 bsmtfin_type_2
# 12             NaN       NaN       NaN            NaN            NaN
# 93             NaN       NaN       NaN            NaN            NaN
# 114            NaN       NaN       NaN            NaN            NaN
# 146            NaN       NaN       NaN            NaN            NaN
# 183            NaN       NaN       NaN            NaN            NaN
# 240            NaN       NaN       NaN            NaN            NaN
# 249            NaN       NaN       NaN            NaN            NaN
# 256            NaN       NaN       NaN            NaN            NaN
# 390            NaN       NaN       NaN            NaN            NaN
# 437            NaN       NaN       NaN            NaN            NaN
# 485            NaN       NaN       NaN            NaN            NaN
# 499            NaN       NaN       NaN            NaN            NaN
# 514            NaN       NaN       NaN            NaN            NaN
# 580            NaN       NaN       NaN            NaN            NaN
# 581            NaN       NaN       NaN            NaN            NaN
# 635            NaN       NaN       NaN            NaN            NaN
# 642            NaN       NaN       NaN            NaN            NaN
# 696            NaN       NaN       NaN            NaN            NaN
# 700            NaN       NaN       NaN            NaN            NaN
# 737            NaN       NaN       NaN            NaN            NaN
# 772            NaN       NaN       NaN            NaN            NaN
# 790            NaN       NaN       NaN            NaN            NaN
# 794            NaN       NaN       NaN            NaN            NaN
# 924            NaN       NaN       NaN            NaN            NaN
# 933            NaN       NaN       NaN            NaN            NaN
# 954            NaN       NaN       NaN            NaN            NaN
# 1007           NaN       NaN       NaN            NaN            NaN
# 1022           NaN       NaN       NaN            NaN            NaN
# 1049           NaN       NaN       NaN            NaN            NaN
# 1089           NaN       NaN       NaN            NaN            NaN
# 1098           NaN       NaN       NaN            NaN            NaN
# 1125           NaN       NaN       NaN            NaN            NaN
# 1157           NaN       NaN       NaN            NaN            NaN
# 1211           NaN       NaN       NaN            NaN            NaN
# 1222           NaN       NaN       NaN            NaN            NaN
# 1252           NaN       NaN       NaN            NaN            NaN
# 1256           NaN       NaN       NaN            NaN            NaN
# 1270           NaN       NaN       NaN            NaN            NaN
# 1331           NaN       NaN       NaN            NaN            NaN
# 1377           NaN       NaN       NaN            NaN            NaN
# 1387           NaN       NaN       NaN            NaN            NaN
# 1428           NaN       NaN       NaN            NaN            NaN
# 1456           NaN        TA        Gd            Unf            Unf
# 1481           NaN       NaN       NaN            NaN            NaN
# 1547           NaN        TA        Gd            Unf            Unf
# 1594           NaN       NaN       NaN            NaN            NaN
# 1620           NaN       NaN       NaN            NaN            NaN
# 1681           NaN       NaN       NaN            NaN            NaN
# 1684           NaN       NaN       NaN            NaN            NaN
# 1686           NaN       NaN       NaN            NaN            NaN
# 1859           NaN       NaN       NaN            NaN            NaN
# 1875           NaN       NaN       NaN            NaN            NaN
# 1889           NaN       NaN       NaN            NaN            NaN
# 1933           NaN       NaN       NaN            NaN            NaN
# 1997           NaN        TA        Gd            Unf            Unf
# 2010           NaN       NaN       NaN            NaN            NaN

# %%
ames_train['bsmt_exposure'].unique()
# Out:
# array(['No', 'Gd', 'Av', nan, 'Mn'], dtype=object)

# %%
ames_train['bsmtfin_type_1'].unique()
# Out:
# array(['GLQ', 'Unf', 'ALQ', 'Rec', nan, 'BLQ', 'LwQ'], dtype=object)

# %%
ames_train['bsmtfin_type_2'].unique()
# Out:
# array(['Unf', 'Rec', nan, 'BLQ', 'GLQ', 'LwQ', 'ALQ'], dtype=object)

# %%
ames_train['bsmt_qual'].unique()
# Out:
# array(['TA', 'Gd', 'Fa', nan, 'Ex', 'Po'], dtype=object)

# %%
ames_train['bsmt_cond'].unique()
# Out:
# array(['TA', 'Gd', nan, 'Fa', 'Po', 'Ex'], dtype=object)

# %%
ames_train['bsmt_exposure'].unique()
# Out:
# array(['No', 'Gd', 'Av', nan, 'Mn'], dtype=object)

# %%
ames_train.at[1997, 'bsmt_exposure'] = 'No'
ames_train.at[1456, 'bsmt_exposure'] = 'No'
ames_train.at[1547, 'bsmt_exposure'] = 'No'

# %%
ames_train['bsmt_exposure'] = ames_train['bsmt_exposure'].fillna('none')
ames_train['bsmt_cond'] = ames_train['bsmt_cond'].fillna('none')
ames_train['bsmt_qual'] = ames_train['bsmt_qual'].fillna('none')
ames_train['bsmtfin_type_1'] = ames_train['bsmtfin_type_1'].fillna('none')
ames_train['bsmtfin_type_2'] = ames_train['bsmtfin_type_2'].fillna('none')

# %% [markdown]
# ### Alley feature

# %%
#The alley feature seems to indicate that the presence of NaN means htere is no alley. I shall replace this with 'none'
alley = ames_train.loc[ames_train['alley'].isnull()][['alley']]
alley
# Out:
#      alley
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# ...    ...
# 2046   NaN
# 2047   NaN
# 2048   NaN
# 2049   NaN
# 2050   NaN
#
# [1908 rows x 1 columns]

# %%
ames_train['alley'].unique()
# Out:
# array([nan, 'Pave', 'Grvl'], dtype=object)

# %%
ames_train['alley'] = ames_train['alley'].fillna('none')

# %% [markdown]
# ### Lot frontage feature

# %%
#The frontage feature seems to indicate that Na values mean there is no street connected to the property. I will replace this with
#0.0.

frontage = ames_train.loc[ames_train['lot_frontage'].isnull()][['lot_frontage']]
frontage
# Out:
#       lot_frontage
# 0              NaN
# 7              NaN
# 8              NaN
# 23             NaN
# 27             NaN
# ...            ...
# 2016           NaN
# 2022           NaN
# 2028           NaN
# 2031           NaN
# 2047           NaN
#
# [330 rows x 1 columns]

# %%
ames_train['lot_frontage'].unique()
# Out:
# array([ nan,  43.,  68.,  73.,  82., 137.,  35.,  70.,  21.,  64., 120.,
#         24.,  74.,  93.,  34.,  80.,  71.,  72., 109.,  40., 103., 100.,
#         92.,  65.,  75.,  60.,  30.,  79.,  41., 105., 107.,  81.,  36.,
#         63.,  32.,  94.,  44.,  50.,  48.,  67.,  88.,  83.,  53.,  58.,
#         57.,  52.,  87., 134.,  56.,  54., 140.,  78.,  85.,  90.,  96.,
#         62.,  49.,  59., 155.,  91.,  61.,  86., 128.,  77.,  42.,  89.,
#         51.,  69.,  55., 112.,  76., 125.,  98., 113., 102.,  22., 122.,
#         84., 119., 118.,  66.,  95., 108., 195., 106.,  39., 110., 130.,
#         97.,  45.,  37.,  38., 129., 115.,  47., 114., 104.,  46., 121.,
#        124., 313., 141., 101.,  99., 160., 174.,  26., 144., 138., 111.,
#         25.,  33., 200., 150., 117., 153., 116., 135.])

# %%
ames_train['lot_frontage'] = ames_train['lot_frontage'].fillna(0.0)

# %% [markdown]
# ### Fireplace feature

# %%
#according to the data dictionary, a nan value means there is no fioreplace. I shall replace it with None. 
fireplace = ames_train.loc[ames_train['fireplace_qu'].isnull()][['fireplace_qu']]

# %%
ames_train['fireplace_qu'].unique()
# Out:
# array([nan, 'TA', 'Gd', 'Po', 'Ex', 'Fa'], dtype=object)

# %%
ames_train['fireplace_qu'] = ames_train['fireplace_qu'].fillna('none')

# %% [markdown]
# ### Garage features

# %%
# Exactly 113 entrees for garage-related features have come up. It is likely these places do not have a garage. I shall replace Nan with 'none'.
garage = ames_train.loc[ames_train['garage_type'].isnull()][['garage_yr_blt','garage_finish', 'garage_qual','garage_cond','garage_type']]
garage
# Out:
#       garage_yr_blt garage_finish garage_qual garage_cond garage_type
# 28              NaN           NaN         NaN         NaN         NaN
# 53              NaN           NaN         NaN         NaN         NaN
# 65              NaN           NaN         NaN         NaN         NaN
# 79              NaN           NaN         NaN         NaN         NaN
# 101             NaN           NaN         NaN         NaN         NaN
# ...             ...           ...         ...         ...         ...
# 1991            NaN           NaN         NaN         NaN         NaN
# 2010            NaN           NaN         NaN         NaN         NaN
# 2027            NaN           NaN         NaN         NaN         NaN
# 2039            NaN           NaN         NaN         NaN         NaN
# 2042            NaN           NaN         NaN         NaN         NaN
#
# [113 rows x 5 columns]

# %%
garage.columns
# Out:
# Index(['garage_yr_blt', 'garage_finish', 'garage_qual', 'garage_cond',
#        'garage_type'],
#       dtype='object')

# %%
# Using .update makes the code more efficient
ames_train.update(ames_train[['garage_type', 'garage_yr_blt', 'garage_finish', 'garage_qual', 'garage_cond']].fillna('none'))

# %% [markdown]
# ### Pool feature

# %%
# Nan would likely mean there is no pool. THis is reinforced by the 0s in pool_area. I shall replace these with 'none'
pool = ames_train.loc[ames_train['pool_qc'].isnull()][['pool_qc', 'pool_area']]
pool
# Out:
#      pool_qc  pool_area
# 0        NaN          0
# 1        NaN          0
# 2        NaN          0
# 3        NaN          0
# 4        NaN          0
# ...      ...        ...
# 2046     NaN          0
# 2047     NaN          0
# 2048     NaN          0
# 2049     NaN          0
# 2050     NaN          0
#
# [2039 rows x 2 columns]

# %%
ames_train['pool_qc'] = ames_train['pool_qc'].fillna('none')

# %% [markdown]
# ### Fence feature

# %%
# A nan value means there is no fence. I shall replace this with 'none'
ames_train.loc[ames_train['fence'].isnull()][['fence']]
# Out:
#      fence
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# ...    ...
# 2046   NaN
# 2047   NaN
# 2048   NaN
# 2049   NaN
# 2050   NaN
#
# [1650 rows x 1 columns]

# %%
ames_train['fence'] = ames_train['fence'].fillna('none')

# %% [markdown]
# ### misc_feature feature

# %%
# Nan values indicate absence of Misc features. in shall replace this with None
ames_train.loc[ames_train['misc_feature'].isnull()][['misc_feature']]
# Out:
#      misc_feature
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# ...           ...
# 2046          NaN
# 2047          NaN
# 2048          NaN
# 2049          NaN
# 2050          NaN
#
# [1983 rows x 1 columns]

# %%
ames_train['misc_feature'].unique()
# Out:
# array([nan, 'Shed', 'TenC', 'Gar2', 'Othr', 'Elev'], dtype=object)

# %%
ames_train['misc_feature'] = ames_train['misc_feature'].fillna('none')

# %% [markdown]
# ## Confirmation of processed test data

# %%
# Print a list of nulls for columns containing nulls

ames_train_nullcount = pd.DataFrame(ames_train.isnull().sum(), columns = ['nulls'])
ames_train_nullcount = ames_train_nullcount[ames_train_nullcount['nulls'] != 0]
print(ames_train_nullcount.shape)
ames_train_nullcount
# Out:
# (0, 1)
# Empty DataFrame
# Columns: [nulls]
# Index: []

# %%
#Visualise where the null columns are
plt.figure(figsize=(15,9))
sns.heatmap(ames_train.isnull())

# %%
#Using a .applymap function, turn all strings into lowercase and all ints into floats
ames_train = ames_train.applymap(lambda s:s.lower() if type(s) == str else float(s))

# %%
ames_train.head()
# Out:
#       id          pid  ms_subclass ms_zoning  lot_frontage  lot_area street  \
# 0  109.0  533352170.0         60.0        rl           0.0   13517.0   pave
# 1  544.0  531379050.0         60.0        rl          43.0   11492.0   pave
# 2  153.0  535304180.0         20.0        rl          68.0    7922.0   pave
# 3  318.0  916386060.0         60.0        rl          73.0    9802.0   pave
# 4  255.0  906425045.0         50.0        rl          82.0   14235.0   pave
#
#   alley lot_shape land_contour  ... screen_porch pool_area pool_qc fence  \
# 0  none       ir1          lvl  ...          0.0       0.0    none  none
# 1  none       ir1          lvl  ...          0.0       0.0    none  none
# 2  none       reg          lvl  ...          0.0       0.0    none  none
# 3  none       reg          lvl  ...          0.0       0.0    none  none
# 4  none       ir1          lvl  ...          0.0       0.0    none  none
#
#   misc_feature misc_val mo_sold yr_sold  sale_type  saleprice
# 0         none      0.0     3.0  2010.0        wd    130500.0
# 1         none      0.0     4.0  2009.0        wd    220000.0
# 2         none      0.0     1.0  2010.0        wd    109000.0
# 3         none      0.0     4.0  2010.0        wd    174000.0
# 4         none      0.0     3.0  2010.0        wd    138500.0
#
# [5 rows x 81 columns]

# %%
ames_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2048 entries, 0 to 2050
# Data columns (total 81 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               2048 non-null   float64
#  1   pid              2048 non-null   float64
#  2   ms_subclass      2048 non-null   float64
#  3   ms_zoning        2048 non-null   object
#  4   lot_frontage     2048 non-null   float64
#  5   lot_area         2048 non-null   float64
#  6   street           2048 non-null   object
#  7   alley            2048 non-null   object
#  8   lot_shape        2048 non-null   object
#  9   land_contour     2048 non-null   object
#  10  utilities        2048 non-null   object
#  11  lot_config       2048 non-null   object
#  12  land_slope       2048 non-null   object
#  13  neighborhood     2048 non-null   object
#  14  condition_1      2048 non-null   object
#  15  condition_2      2048 non-null   object
#  16  bldg_type        2048 non-null   object
#  17  house_style      2048 non-null   object
#  18  overall_qual     2048 non-null   float64
#  19  overall_cond     2048 non-null   float64
#  20  year_built       2048 non-null   float64
#  21  year_remod/add   2048 non-null   float64
#  22  roof_style       2048 non-null   object
#  23  roof_matl        2048 non-null   object
#  24  exterior_1st     2048 non-null   object
#  25  exterior_2nd     2048 non-null   object
#  26  mas_vnr_type     2048 non-null   object
#  27  mas_vnr_area     2048 non-null   float64
#  28  exter_qual       2048 non-null   object
#  29  exter_cond       2048 non-null   object
#  30  foundation       2048 non-null   object
#  31  bsmt_qual        2048 non-null   object
#  32  bsmt_cond        2048 non-null   object
#  33  bsmt_exposure    2048 non-null   object
#  34  bsmtfin_type_1   2048 non-null   object
#  35  bsmtfin_sf_1     2048 non-null   float64
#  36  bsmtfin_type_2   2048 non-null   object
#  37  bsmtfin_sf_2     2048 non-null   float64
#  38  bsmt_unf_sf      2048 non-null   float64
#  39  total_bsmt_sf    2048 non-null   float64
#  40  heating          2048 non-null   object
#  41  heating_qc       2048 non-null   object
#  42  central_air      2048 non-null   object
#  43  electrical       2048 non-null   object
#  44  1st_flr_sf       2048 non-null   float64
#  45  2nd_flr_sf       2048 non-null   float64
#  46  low_qual_fin_sf  2048 non-null   float64
#  47  gr_liv_area      2048 non-null   float64
#  48  bsmt_full_bath   2048 non-null   float64
#  49  bsmt_half_bath   2048 non-null   float64
#  50  full_bath        2048 non-null   float64
#  51  half_bath        2048 non-null   float64
#  52  bedroom_abvgr    2048 non-null   float64
#  53  kitchen_abvgr    2048 non-null   float64
#  54  kitchen_qual     2048 non-null   object
#  55  totrms_abvgrd    2048 non-null   float64
#  56  functional       2048 non-null   object
#  57  fireplaces       2048 non-null   float64
#  58  fireplace_qu     2048 non-null   object
#  59  garage_type      2048 non-null   object
#  60  garage_yr_blt    2048 non-null   object
#  61  garage_finish    2048 non-null   object
#  62  garage_cars      2048 non-null   float64
#  63  garage_area      2048 non-null   float64
#  64  garage_qual      2048 non-null   object
#  65  garage_cond      2048 non-null   object
#  66  paved_drive      2048 non-null   object
#  67  wood_deck_sf     2048 non-null   float64
#  68  open_porch_sf    2048 non-null   float64
#  69  enclosed_porch   2048 non-null   float64
#  70  3ssn_porch       2048 non-null   float64
#  71  screen_porch     2048 non-null   float64
#  72  pool_area        2048 non-null   float64
#  73  pool_qc          2048 non-null   object
#  74  fence            2048 non-null   object
#  75  misc_feature     2048 non-null   object
#  76  misc_val         2048 non-null   float64
#  77  mo_sold          2048 non-null   float64
#  78  yr_sold          2048 non-null   float64
#  79  sale_type        2048 non-null   object
#  80  saleprice        2048 non-null   float64
# dtypes: float64(38), object(43)
# memory usage: 1.4+ MB

# %%
# save processed data as 'train_cleaned.csv'
ames_train.to_csv('./datasets/train_cleaned.csv')

# %% [markdown]
# # Initial analysis for test set
#
# ---

# %%
#Make all columns lowercase and replace spaces with '_'
ames_test.columns = ames_test.columns.str.lower()
ames_test.columns = ames_test.columns.str.replace(' ', '_')

# %%
ames_test.head()
# Out:
#      id        pid  ms_subclass ms_zoning  lot_frontage  lot_area street  \
# 0  2658  902301120          190        RM          69.0      9142   Pave
# 1  2718  905108090           90        RL           NaN      9662   Pave
# 2  2414  528218130           60        RL          58.0     17104   Pave
# 3  1989  902207150           30        RM          60.0      8520   Pave
# 4   625  535105100           20        RL           NaN      9500   Pave
#
#   alley lot_shape land_contour  ... 3ssn_porch screen_porch pool_area pool_qc  \
# 0  Grvl       Reg          Lvl  ...          0            0         0     NaN
# 1   NaN       IR1          Lvl  ...          0            0         0     NaN
# 2   NaN       IR1          Lvl  ...          0            0         0     NaN
# 3   NaN       Reg          Lvl  ...          0            0         0     NaN
# 4   NaN       IR1          Lvl  ...          0          185         0     NaN
#
#   fence misc_feature misc_val mo_sold  yr_sold  sale_type
# 0   NaN          NaN        0       4     2006        WD
# 1   NaN          NaN        0       8     2006        WD
# 2   NaN          NaN        0       9     2006        New
# 3   NaN          NaN        0       7     2007        WD
# 4   NaN          NaN        0       7     2009        WD
#
# [5 rows x 80 columns]

# %%
ames_test.shape
# Out:
# (879, 80)

# %%
ames_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 879 entries, 0 to 878
# Data columns (total 80 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               879 non-null    int64
#  1   pid              879 non-null    int64
#  2   ms_subclass      879 non-null    int64
#  3   ms_zoning        879 non-null    object
#  4   lot_frontage     719 non-null    float64
#  5   lot_area         879 non-null    int64
#  6   street           879 non-null    object
#  7   alley            58 non-null     object
#  8   lot_shape        879 non-null    object
#  9   land_contour     879 non-null    object
#  10  utilities        879 non-null    object
#  11  lot_config       879 non-null    object
#  12  land_slope       879 non-null    object
#  13  neighborhood     879 non-null    object
#  14  condition_1      879 non-null    object
#  15  condition_2      879 non-null    object
#  16  bldg_type        879 non-null    object
#  17  house_style      879 non-null    object
#  18  overall_qual     879 non-null    int64
#  19  overall_cond     879 non-null    int64
#  20  year_built       879 non-null    int64
#  21  year_remod/add   879 non-null    int64
#  22  roof_style       879 non-null    object
#  23  roof_matl        879 non-null    object
#  24  exterior_1st     879 non-null    object
#  25  exterior_2nd     879 non-null    object
#  26  mas_vnr_type     878 non-null    object
#  27  mas_vnr_area     878 non-null    float64
#  28  exter_qual       879 non-null    object
#  29  exter_cond       879 non-null    object
#  30  foundation       879 non-null    object
#  31  bsmt_qual        854 non-null    object
#  32  bsmt_cond        854 non-null    object
#  33  bsmt_exposure    854 non-null    object
#  34  bsmtfin_type_1   854 non-null    object
#  35  bsmtfin_sf_1     879 non-null    int64
#  36  bsmtfin_type_2   854 non-null    object
#  37  bsmtfin_sf_2     879 non-null    int64
#  38  bsmt_unf_sf      879 non-null    int64
#  39  total_bsmt_sf    879 non-null    int64
#  40  heating          879 non-null    object
#  41  heating_qc       879 non-null    object
#  42  central_air      879 non-null    object
#  43  electrical       878 non-null    object
#  44  1st_flr_sf       879 non-null    int64
#  45  2nd_flr_sf       879 non-null    int64
#  46  low_qual_fin_sf  879 non-null    int64
#  47  gr_liv_area      879 non-null    int64
#  48  bsmt_full_bath   879 non-null    int64
#  49  bsmt_half_bath   879 non-null    int64
#  50  full_bath        879 non-null    int64
#  51  half_bath        879 non-null    int64
#  52  bedroom_abvgr    879 non-null    int64
#  53  kitchen_abvgr    879 non-null    int64
#  54  kitchen_qual     879 non-null    object
#  55  totrms_abvgrd    879 non-null    int64
#  56  functional       879 non-null    object
#  57  fireplaces       879 non-null    int64
#  58  fireplace_qu     457 non-null    object
#  59  garage_type      835 non-null    object
#  60  garage_yr_blt    834 non-null    float64
#  61  garage_finish    834 non-null    object
#  62  garage_cars      879 non-null    int64
#  63  garage_area      879 non-null    int64
#  64  garage_qual      834 non-null    object
#  65  garage_cond      834 non-null    object
#  66  paved_drive      879 non-null    object
#  67  wood_deck_sf     879 non-null    int64
#  68  open_porch_sf    879 non-null    int64
#  69  enclosed_porch   879 non-null    int64
#  70  3ssn_porch       879 non-null    int64
#  71  screen_porch     879 non-null    int64
#  72  pool_area        879 non-null    int64
#  73  pool_qc          4 non-null      object
#  74  fence            172 non-null    object
#  75  misc_feature     41 non-null     object
#  76  misc_val         879 non-null    int64
#  77  mo_sold          879 non-null    int64
#  78  yr_sold          879 non-null    int64
#  79  sale_type        879 non-null    object
# dtypes: float64(3), int64(35), object(42)
# memory usage: 549.5+ KB

# %%
# Print a list of nulls for columns containing nulls

ames_test_nullcount = pd.DataFrame(ames_test.isnull().sum(), columns = ['nulls'])
ames_test_nullcount = ames_test_nullcount[ames_test_nullcount['nulls'] != 0]
print(ames_test_nullcount.shape)
ames_test_nullcount
# Out:
# (19, 1)
#                 nulls
# lot_frontage      160
# alley             821
# mas_vnr_type        1
# mas_vnr_area        1
# bsmt_qual          25
# bsmt_cond          25
# bsmt_exposure      25
# bsmtfin_type_1     25
# bsmtfin_type_2     25
# electrical          1
# fireplace_qu      422
# garage_type        44
# garage_yr_blt      45
# garage_finish      45
# garage_qual        45
# garage_cond        45
# pool_qc           875
# fence             707
# misc_feature      838

# %% [markdown]
# The list of nulls appear to be similar to the test set except for the 'Electrical feature which should be investigated further

# %% [markdown]
# ## Investigate and resolve nullcounts
# ---

# %% [markdown]
# ### Electrical Feature

# %%
# This appears to be an entry error as the 'utilities' section describes the house as having electricity, gas, water and sewage
ames_test.loc[ames_test['electrical'].isnull()][['electrical', 'utilities']]
# Out:
#     electrical utilities
# 635        NaN    AllPub

# %%
ames_test[['electrical', 'utilities']]
# Out:
#     electrical utilities
# 0        FuseP    AllPub
# 1        SBrkr    AllPub
# 2        SBrkr    AllPub
# 3        SBrkr    AllPub
# 4        SBrkr    AllPub
# ..         ...       ...
# 874      SBrkr    AllPub
# 875      SBrkr    AllPub
# 876      SBrkr    AllPub
# 877      SBrkr    AllPub
# 878      SBrkr    AllPub
#
# [879 rows x 2 columns]

# %%
# Only 1 entry does not have all public utilities. Even then, there os a Fuse system availableele
ames_test.loc[ames_test['utilities'] != 'AllPub'][['electrical', 'utilities']]
# Out:
#     electrical utilities
# 144      FuseA    NoSewr

# %%
# Only 65 out of 859 entries still utilise a system of wired fuses. I posit thatthe missing 'electrical'
#feature is likely to be a 'SBrkr' and I will place it as such
ames_test.loc[ames_test['electrical'] != 'SBrkr'][['electrical', 'utilities']]
# Out:
#     electrical utilities
# 0        FuseP    AllPub
# 17       FuseA    AllPub
# 27       FuseA    AllPub
# 29       FuseA    AllPub
# 31       FuseA    AllPub
# ..         ...       ...
# 775      FuseF    AllPub
# 780      FuseA    AllPub
# 802      FuseF    AllPub
# 819      FuseF    AllPub
# 835      FuseA    AllPub
#
# [65 rows x 2 columns]

# %%
ames_test.at[635, 'electrical'] = 'SBrkr'

# %%
# Print a list of nulls for columns containing nulls

ames_test_nullcount = pd.DataFrame(ames_test.isnull().sum(), columns = ['nulls'])
ames_test_nullcount = ames_test_nullcount[ames_test_nullcount['nulls'] != 0]
print(ames_test_nullcount.shape)
ames_test_nullcount
# Out:
# (18, 1)
#                 nulls
# lot_frontage      160
# alley             821
# mas_vnr_type        1
# mas_vnr_area        1
# bsmt_qual          25
# bsmt_cond          25
# bsmt_exposure      25
# bsmtfin_type_1     25
# bsmtfin_type_2     25
# fireplace_qu      422
# garage_type        44
# garage_yr_blt      45
# garage_finish      45
# garage_qual        45
# garage_cond        45
# pool_qc           875
# fence             707
# misc_feature      838

# %% [markdown]
# ### Mass_vnr feature

# %%
# As with the train set Nan values seem to indicate the absence of mas_vnr. I shall replace NaN in Mass_vnr_typr with 'none'
# and mas_vnr_area with 0.0
mas_vnr = ames_test.loc[ames_test['mas_vnr_area'].isnull()][['mas_vnr_type','mas_vnr_area']]
print(mas_vnr.shape)
mas_vnr
# Out:
# (1, 2)
#     mas_vnr_type  mas_vnr_area
# 866          NaN           NaN

# %%
ames_test['mas_vnr_type'] = ames_test['mas_vnr_type'].fillna('none')

ames_test['mas_vnr_area'] = ames_test['mas_vnr_area'].fillna(0.0)

# %%
#Resolve alley and frontage features
ames_test['alley'] = ames_test['alley'].fillna('none')
ames_test['lot_frontage'] = ames_test['lot_frontage'].fillna(0.0)

#resolve basement features
ames_test.update(ames_test[['bsmt_exposure', 'bsmt_cond', 'bsmt_qual', 'bsmtfin_type_1', 'bsmtfin_type_2']].fillna('none'))

#resolve fireplace features
ames_test['fireplace_qu'] = ames_test['fireplace_qu'].fillna('none')

#resolve garage feature
ames_test.update(ames_test[['garage_type', 'garage_yr_blt', 'garage_finish', 'garage_qual', 'garage_cond']].fillna('none'))

#resolve misc features
ames_test['misc_feature'] = ames_test['misc_feature'].fillna('none')

#resolve pool features
ames_test['pool_qc'] = ames_test['pool_qc'].fillna('none')

#resolve pool features
ames_test['fence'] = ames_test['fence'].fillna('none')

# %% [markdown]
# ## Confirmation of processed train data

# %%
# Print a list of nulls for columns containing nulls

ames_test_nullcount = pd.DataFrame(ames_test.isnull().sum(), columns = ['nulls'])
ames_test_nullcount = ames_test_nullcount[ames_test_nullcount['nulls'] != 0]
print(ames_test_nullcount.shape)
ames_test_nullcount
# Out:
# (0, 1)
# Empty DataFrame
# Columns: [nulls]
# Index: []

# %%
#Using a .applymap function, turn all strings into lowercase and all ints into floats
ames_test = ames_test.applymap(lambda s:s.lower() if type(s) == str else float(s))

# %%
ames_test.head()
# Out:
#        id          pid  ms_subclass ms_zoning  lot_frontage  lot_area street  \
# 0  2658.0  902301120.0        190.0        rm          69.0    9142.0   pave
# 1  2718.0  905108090.0         90.0        rl           0.0    9662.0   pave
# 2  2414.0  528218130.0         60.0        rl          58.0   17104.0   pave
# 3  1989.0  902207150.0         30.0        rm          60.0    8520.0   pave
# 4   625.0  535105100.0         20.0        rl           0.0    9500.0   pave
#
#   alley lot_shape land_contour  ... 3ssn_porch screen_porch pool_area pool_qc  \
# 0  grvl       reg          lvl  ...        0.0          0.0       0.0    none
# 1  none       ir1          lvl  ...        0.0          0.0       0.0    none
# 2  none       ir1          lvl  ...        0.0          0.0       0.0    none
# 3  none       reg          lvl  ...        0.0          0.0       0.0    none
# 4  none       ir1          lvl  ...        0.0        185.0       0.0    none
#
#   fence misc_feature misc_val mo_sold  yr_sold  sale_type
# 0  none         none      0.0     4.0   2006.0        wd
# 1  none         none      0.0     8.0   2006.0        wd
# 2  none         none      0.0     9.0   2006.0        new
# 3  none         none      0.0     7.0   2007.0        wd
# 4  none         none      0.0     7.0   2009.0        wd
#
# [5 rows x 80 columns]

# %%
ames_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 879 entries, 0 to 878
# Data columns (total 80 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               879 non-null    float64
#  1   pid              879 non-null    float64
#  2   ms_subclass      879 non-null    float64
#  3   ms_zoning        879 non-null    object
#  4   lot_frontage     879 non-null    float64
#  5   lot_area         879 non-null    float64
#  6   street           879 non-null    object
#  7   alley            879 non-null    object
#  8   lot_shape        879 non-null    object
#  9   land_contour     879 non-null    object
#  10  utilities        879 non-null    object
#  11  lot_config       879 non-null    object
#  12  land_slope       879 non-null    object
#  13  neighborhood     879 non-null    object
#  14  condition_1      879 non-null    object
#  15  condition_2      879 non-null    object
#  16  bldg_type        879 non-null    object
#  17  house_style      879 non-null    object
#  18  overall_qual     879 non-null    float64
#  19  overall_cond     879 non-null    float64
#  20  year_built       879 non-null    float64
#  21  year_remod/add   879 non-null    float64
#  22  roof_style       879 non-null    object
#  23  roof_matl        879 non-null    object
#  24  exterior_1st     879 non-null    object
#  25  exterior_2nd     879 non-null    object
#  26  mas_vnr_type     879 non-null    object
#  27  mas_vnr_area     879 non-null    float64
#  28  exter_qual       879 non-null    object
#  29  exter_cond       879 non-null    object
#  30  foundation       879 non-null    object
#  31  bsmt_qual        879 non-null    object
#  32  bsmt_cond        879 non-null    object
#  33  bsmt_exposure    879 non-null    object
#  34  bsmtfin_type_1   879 non-null    object
#  35  bsmtfin_sf_1     879 non-null    float64
#  36  bsmtfin_type_2   879 non-null    object
#  37  bsmtfin_sf_2     879 non-null    float64
#  38  bsmt_unf_sf      879 non-null    float64
#  39  total_bsmt_sf    879 non-null    float64
#  40  heating          879 non-null    object
#  41  heating_qc       879 non-null    object
#  42  central_air      879 non-null    object
#  43  electrical       879 non-null    object
#  44  1st_flr_sf       879 non-null    float64
#  45  2nd_flr_sf       879 non-null    float64
#  46  low_qual_fin_sf  879 non-null    float64
#  47  gr_liv_area      879 non-null    float64
#  48  bsmt_full_bath   879 non-null    float64
#  49  bsmt_half_bath   879 non-null    float64
#  50  full_bath        879 non-null    float64
#  51  half_bath        879 non-null    float64
#  52  bedroom_abvgr    879 non-null    float64
#  53  kitchen_abvgr    879 non-null    float64
#  54  kitchen_qual     879 non-null    object
#  55  totrms_abvgrd    879 non-null    float64
#  56  functional       879 non-null    object
#  57  fireplaces       879 non-null    float64
#  58  fireplace_qu     879 non-null    object
#  59  garage_type      879 non-null    object
#  60  garage_yr_blt    879 non-null    object
#  61  garage_finish    879 non-null    object
#  62  garage_cars      879 non-null    float64
#  63  garage_area      879 non-null    float64
#  64  garage_qual      879 non-null    object
#  65  garage_cond      879 non-null    object
#  66  paved_drive      879 non-null    object
#  67  wood_deck_sf     879 non-null    float64
#  68  open_porch_sf    879 non-null    float64
#  69  enclosed_porch   879 non-null    float64
#  70  3ssn_porch       879 non-null    float64
#  71  screen_porch     879 non-null    float64
#  72  pool_area        879 non-null    float64
#  73  pool_qc          879 non-null    object
#  74  fence            879 non-null    object
#  75  misc_feature     879 non-null    object
#  76  misc_val         879 non-null    float64
#  77  mo_sold          879 non-null    float64
#  78  yr_sold          879 non-null    float64
#  79  sale_type        879 non-null    object
# dtypes: float64(37), object(43)
# memory usage: 549.5+ KB

# %%
# save processed data as 'test_cleaned.csv'
ames_test.to_csv('./datasets/test_cleaned.csv')

# %% [markdown]
# # Summary

# %% [markdown]
# The above analysis revealed several issues with the presence of null values. These features will be cleaned and preprocessed in the next notebook in this project. These issues have been resolved with both the 'train.csv' and 'test.csv dataset' and saved as 'train_cleaned.csv' and test_cleaned.csv ready for additional exploratory data analysis (EDA) and data-preprocessing before modelling.
